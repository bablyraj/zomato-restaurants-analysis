# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="15%">
#             <img src="GL-2.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=24px>
#                     <b>Exploratory Data Analysis
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Problem Statement
#
# The Zomato exploratory data analysis aims to assist food enthusiasts in discovering the best restaurants and value-for-money options within their locality. It facilitates locating desired cuisines available nearby. With a dataset encompassing restaurant details like establishment type, address, city, locality, and cuisine offerings, alongside attributes such as average cost for two, price range, and aggregate ratings, the objective is to uncover insights into restaurant preferences and dining trends. Through analyzing factors like average cost, ratings, and customer engagement metrics such as votes and photo counts, this study seeks to provide actionable recommendations for diners seeking satisfying dining experiences.

# %% [markdown]
# ## Data Definition
#
# **res_id**: The code given to a restaurant (Categorical)
#
# **name**: Name of the restaurant (Categorical)
#
# **establishment**: Represents the type of establishment (Categorical)
#
# **url**: The website of the restaurant (Categorical)
#
# **address**: The address of the restaurant (Categorical)
#
# **city**: City in which the restaurant located (Categorical)
#
# **city_id**: The code given to a city (Categorical)
#
# **locality**: Locality of the restaurant (Categorical)
#
# **latitude**: Latitude of the restaurant (Categorical)
#
# **longitude**: Longitude of the restaurant (Categorical)
#
# **zipcode**: Zipcode of the city in which the restaurant located (Categorical)
#
# **country_id**: Country code in which the restaurant located (Categorical)
#
# **locality_verbose**: Locality along with the city in which the restaurant located (Categorical)
#
# **cuisines**: The cuisines a restaurant serves (Categorical)
#
# **timings**: The working hours of a restaurant (Categorical)
#
# **average_cost_for_two**: The average amount expected for 2 people (Numerical)
#
# **price_range**: The categories for average cost (Categories - 1,2,3,4) (Categorical)
#
# **currency**: The currency in which a customer pays (Categorical)
#
# **highlights**: The facilities of the restaurant (Categorical)
#
# **aggregate_rating**: The overall rating a restaurant has got (Numerical)
#
# **rating_text**: Categorized ratings (Categorical)
#
# **votes**: Number of votes received by the restaurant from customers (Numerical)
#
# **photo_count**: The number of photos of a restaurant (Numerical)
#
# **opentable_support**: Restaurant reservation from Opentable (Categorical)
#
# **delivery**: The restaurant deliver an order or not (Categorical)
#
# **takeaway**: The restaurant allows  a 'takeaway' of an order or not (Categorical)

# %% [markdown]
# ## Icon Legends
# <table>
#   <tr>
#     <th width="25%"> <img src="infer.png" style="width:25%;"></th>
#     <th width="25%"> <img src="alsoreadicon.png" style="width:25%;"></th>
#     <th width="25%"> <img src="todo.png" style="width:25%;"></th>
#     <th width="25%"> <img src="quicktip.png" style="width:25%;"></th>
#   </tr>
#   <tr>
#     <td><div align="center" style="font-size:120%">
#         <font color="#21618C"><b>Inferences from Outcome</b></font></div>
#     </td>
#     <td><div align="center" style="font-size:120%">
#         <font color="#21618C"><b>Additional Reads</b></font></div>
#     </td>
#     <td><div align="center" style="font-size:120%">
#         <font color="#21618C"><b>Lets do it</b></font></div>
#     </td>
#     <td><div align="center" style="font-size:120%">
#         <font color="#21618C"><b>Quick Tips</b></font></div>
#     </td>
#
# </tr>
#
# </table>

# %% [markdown]
# ## Table of Contents
#
# 1. **[Import Libraries](#import_lib)**
# 2. **[Set Options](#set_options)**
# 3. **[Read Data](#Read_Data)**
# 4. **[Understand  and Prepare the Data](#Understand_Data)**
# 5. **[Understand the variables](#Understanding_variables)**
# 6. **[Check for Missing Values](#missing)**
# 7. **[Study Correlation](#correlation)**
# 8. **[Detect Outliers](#outliers)**
# 9. **[Create a new variable 'region'](#region)**
# 10. **[Some more analysis](#more)**

# %% [markdown]
# <a id='import_lib'></a>
# ## 1. Import Libraries

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="8%">
#             <img src="todo.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>Let us import the required libraries</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# <a id='set_options'></a>
# ## 2. Set Options

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="8%">
#             <img src="todo.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>Now we make necessary changes to :<br><br>
# 1. Display complete data frames<br>
# 2. To set the decimal place of a numeric output to 6 <br>
# 3. Set the working directory
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# Display complete data frames
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Set the decimal place of a numeric output to 6
pd.set_option('display.float_format', lambda x: '%.6f' % x)

# Set the working directory
os.chdir('/Users/bablyraj/Desktop/Project')

# %% [markdown]
# <a id='Read_Data'></a>
# ## 3. Read Data

# %%
# Load the CSV file
df = pd.read_csv('ZomatoRestaurantsIndia.csv')

# %% [markdown]
# <a id='Understand_Data'></a>
# ## 4. Understand  and Prepare the Data

# %% [markdown]
# A well-prepared data proves beneficial for analysis as it limits errors and inaccuracies that can occur during analysis. The processed data is more accessible to users.<br> <br>
#                          Data understanding is the process of getting familiar with the data, to identify data type, to discover first insights into the data, or to detect interesting subsets to form hypotheses about hidden information. Whereas, data preparation is the process of cleaning and transforming raw data before analysis. It is an important step before processing and often involves reformatting data, making corrections to data. <br> <br>
#                         Data preparation is often a lengthy process, but it is essential as a prerequisite to put data in context to get insights and eliminate bias resulting from poor data quality.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="8%">
#             <img src="todo.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> Here we will analyze and prepare data:<br>
#                         1. Check dimensions of the dataframe <br>
#                         2. View the head of the data<br>
#                         3. Note the redundant variables and drop them <br>
#                         4. Check the data types. Refer to data definition to ensure your data types are correct. If data types are not as per business context, change the data types as per requirement <br>
#                         5. Check for duplicates<br>
#                         Note: It is an art to explore data and one will need more and more practice to gain expertise in this area
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
## The columns `'url', 'address', 'latitude', 'longitude', 'zipcode', 'locality_verbose'` are considered redundant because they provide detailed location information that may not be necessary for the analysis. Here are the reasons for each column:

## 1. **`url`**: This column contains the URL of the restaurant's page on Zomato. It is not useful for analysis purposes.
## 2. **`address`**: The detailed address is often not needed for analysis, especially when we have other location-related columns like `city` and `locality`.
## 3. **`latitude`** and **`longitude`**: These columns provide precise geographical coordinates, which might be too detailed for the scope of the analysis.
## 4. **`zipcode`**: The postal code might not add significant value to the analysis if we already have the `city` and `locality` columns.
## 5. **`locality_verbose`**: This column is a combination of `locality` and `city`, which are already present as separate columns.

## By removing these columns, we simplify the dataset and focus on the more relevant features for analysis.

# %% [markdown]
# **1. Check dimensions of the dataframe in terms of rows and columns**

# %%
df.shape
# Out:
# (211944, 26)

# %% [markdown]
# **2. View the head of the data**

# %%
# 2. View the head of the data
print("Head of the dataframe:")
df.head()
# Out:
# Head of the dataframe:
#     res_id                            name  establishment  \
# 0  3400299                     Bikanervala    Quick Bites
# 1  3400005  Mama Chicken Mama Franky House    Quick Bites
# 2  3401013                   Bhagat Halwai    Quick Bites
# 3  3400290                   Bhagat Halwai    Quick Bites
# 4  3401744     The Salt Cafe Kitchen & Bar  Casual Dining
#
#                                                  url  \
# 0  https://www.zomato.com/agra/bikanervala-khanda...
# 1  https://www.zomato.com/agra/mama-chicken-mama-...
# 2  https://www.zomato.com/agra/bhagat-halwai-2-sh...
# 3  https://www.zomato.com/agra/bhagat-halwai-civi...
# 4  https://www.zomato.com/agra/the-salt-cafe-kitc...
#
#                                              address  city  city_id  \
# 0  Kalyani Point, Near Tulsi Cinema, Bypass Road,...  Agra       34
# 1        Main Market, Sadar Bazaar, Agra Cantt, Agra  Agra       34
# ...

# %% [markdown]
# **3. Note the redundant variables and drop them**

# %%
# 3. Note the redundant variables and drop them
redundant_vars = ['url', 'address', 'latitude', 'longitude', 'zipcode', 'locality_verbose','opentable_support']
df.drop(columns=redundant_vars, inplace=True)
print("Columns after dropping redundant variables:")
df.columns
# Out:
# Columns after dropping redundant variables:
# Index(['res_id', 'name', 'establishment', 'city', 'city_id', 'locality',
#        'country_id', 'cuisines', 'timings', 'average_cost_for_two',
#        'price_range', 'currency', 'highlights', 'aggregate_rating',
#        'rating_text', 'votes', 'photo_count', 'delivery', 'takeaway'],
#       dtype='object')

# %%
df.head()   # Display the head of the data
# Out:
#     res_id                            name  establishment  city  city_id  \
# 0  3400299                     Bikanervala    Quick Bites  Agra       34
# 1  3400005  Mama Chicken Mama Franky House    Quick Bites  Agra       34
# 2  3401013                   Bhagat Halwai    Quick Bites  Agra       34
# 3  3400290                   Bhagat Halwai    Quick Bites  Agra       34
# 4  3401744     The Salt Cafe Kitchen & Bar  Casual Dining  Agra       34
#
#       locality  country_id                                           cuisines  \
# 0     Khandari           1  North Indian, South Indian, Mithai, Street Foo...
# 1   Agra Cantt           1  North Indian, Mughlai, Rolls, Chinese, Fast Fo...
# 2     Shahganj           1                                  Fast Food, Mithai
# 3  Civil Lines           1          Desserts, Bakery, Fast Food, South Indian
# 4      Tajganj           1                 North Indian, Continental, Italian
#
# ...

# %% [markdown]
# **4. Check the data types. Refer to data definition to ensure your data types are correct. If data types are not as per business context, change the data types as per requirement**

# %%
# 4. Check the data types
print("Data types of the dataframe:")
df.dtypes
# Out:
# Data types of the dataframe:
# res_id                    int64
# name                     object
# establishment            object
# city                     object
# city_id                   int64
# locality                 object
# country_id                int64
# cuisines                 object
# timings                  object
# average_cost_for_two      int64
# price_range               int64
# currency                 object
# highlights               object
# aggregate_rating        float64
# rating_text              object
# votes                     int64
# photo_count               int64
# delivery                  int64
# takeaway                  int64
# dtype: object

# %%
# Update data types (if needed)
df['delivery'] = df['delivery'].astype(bool)  # Example: Convert 'delivery' to boolean
df['takeaway'] = df['takeaway'].astype(bool)  # Example: Convert 'takeaway' to boolean

# %%
df.dtypes  # Check the data types after updating
# Out:
# res_id                    int64
# name                     object
# establishment            object
# city                     object
# city_id                   int64
# locality                 object
# country_id                int64
# cuisines                 object
# timings                  object
# average_cost_for_two      int64
# price_range               int64
# currency                 object
# highlights               object
# aggregate_rating        float64
# rating_text              object
# votes                     int64
# photo_count               int64
# delivery                   bool
# takeaway                   bool
# dtype: object

# %% [markdown]
# **5. Check for Duplicates**

# %%
# 5. Check and remove duplicates
df.duplicated().sum()
df = df.drop_duplicates()

# %%
df.duplicated().sum()  # Check if duplicates are removed
# Out:
# 0

# %%
df.shape  # Check the shape of the data after removing duplicates
# Out:
# (56521, 19)

# %%
df.head()  # Display the head of the data
# Out:
#     res_id                            name  establishment  city  city_id  \
# 0  3400299                     Bikanervala    Quick Bites  Agra       34
# 1  3400005  Mama Chicken Mama Franky House    Quick Bites  Agra       34
# 2  3401013                   Bhagat Halwai    Quick Bites  Agra       34
# 3  3400290                   Bhagat Halwai    Quick Bites  Agra       34
# 4  3401744     The Salt Cafe Kitchen & Bar  Casual Dining  Agra       34
#
#       locality  country_id                                           cuisines  \
# 0     Khandari           1  North Indian, South Indian, Mithai, Street Foo...
# 1   Agra Cantt           1  North Indian, Mughlai, Rolls, Chinese, Fast Fo...
# 2     Shahganj           1                                  Fast Food, Mithai
# 3  Civil Lines           1          Desserts, Bakery, Fast Food, South Indian
# 4      Tajganj           1                 North Indian, Continental, Italian
#
# ...

# %% [markdown]
# <a id = 'Understanding_variables'> </a>
# ## 5. Understand the variables

# %% [markdown]
# **1. Variable 'name'**

# %%
df['name'].nunique()  # Check the number of unique restaurants
# Out:
# 40965

# %%
unique_cities = df['city'].nunique()
print(unique_cities)
# Out:
# 98

# %% [markdown]
# **2. Variable 'establishment'**

# %%
df['establishment'].value_counts() # Check the number of restaurants by establishment type
# Out:
# establishment
# Quick Bites        14202
# Casual Dining      12608
# Café                4241
# Bakery              3753
# Dessert Parlour     3700
# Sweet Shop          2627
# Beverage Shop       2453
# Fine Dining         1596
# Food Court          1499
# Bar                 1496
# Dhaba               1285
# Kiosk               1130
# Food Truck           868
# Lounge               867
# Bhojanalya           633
# Pub                  373
# Mess                 365
# Paan Shop            320
# Confectionery        219
# Butcher Shop         154
# Microbrewery         122
# Club                 113
# Shack                 20
# Cocktail Bar          17
# Irani Cafe            14
# Pop up                 4
# Name: count, dtype: int64

# %%
unique_establishments = df['establishment'].nunique()
print(unique_establishments)
# Out:
# 26

# %% [markdown]
# **3. Variable 'city'**

# %%
print(df['city'].value_counts().head(10))  # Check the top 10 city in the data
# Out:
# city
# Bangalore    2270
# Mumbai       2220
# Chennai      1955
# Pune         1866
# New Delhi    1765
# Jaipur       1412
# Kolkata      1366
# Ahmedabad    1291
# Lucknow      1188
# Goa          1169
# Name: count, dtype: int64

# %% [markdown]
# **4. Variable 'locality'**

# %%
print(df['locality'].value_counts().head(10))  # Check the top 10 locality in the data
# Out:
# locality
# Civil Lines      758
# Model Town       458
# Shastri Nagar    393
# Vijay Nagar      391
# Gomti Nagar      282
# Lashkar          224
# College Road     222
# CIDCO            211
# Tirumala         208
# Bistupur         206
# Name: count, dtype: int64

# %% [markdown]
# **5. Variable 'cuisines'**

# %%
print(df['cuisines'].value_counts().head(10))  # Check the top 10 cuisines in the data
# Out:
# cuisines
# North Indian             4334
# Fast Food                2032
# North Indian, Chinese    1652
# Bakery                   1588
# South Indian             1508
# Street Food              1193
# Cafe                     1119
# Mithai                   1021
# Desserts                  926
# Bakery, Desserts          839
# Name: count, dtype: int64

# %% [markdown]
# **7. Variable 'average_cost_for_two'**

# %%
print(df['average_cost_for_two'].value_counts().head(10))  # Check the top 10 average_cost_for_two in the data
# Out:
# average_cost_for_two
# 200    6671
# 300    6473
# 400    5274
# 500    4809
# 100    4652
# 150    3898
# 250    3515
# 600    2754
# 800    1997
# 350    1960
# Name: count, dtype: int64

# %% [markdown]
# **8. Variable 'price_range'**

# %%
print(df['price_range'].value_counts().head(10))  # Check the top 10 price_range in the data
# Out:
# price_range
# 1    29009
# 2    16838
# 3     7719
# 4     2955
# Name: count, dtype: int64

# %% [markdown]
# **9. Variable 'highlights'**

# %%
print(df['highlights'].value_counts().head(10))  # Check the top 10 highlights in the data
# Out:
# highlights
# Dinner, Takeaway Available, Lunch, Cash, Indoor Seating                                                        865
# Dinner, Delivery, Lunch, Cash, Takeaway Available, Indoor Seating                                              575
# Takeaway Available, Cash, Indoor Seating, Desserts and Bakes                                                   368
# Cash, Takeaway Available                                                                                       345
# No Seating Available, Takeaway Available, Cash, Desserts and Bakes                                             320
# Cash                                                                                                           288
# Cash, Takeaway Available, Indoor Seating                                                                       237
# Dinner, Cash, Takeaway Available, Debit Card, Lunch, Delivery, Credit Card, Indoor Seating, Air Conditioned    213
# ...

# %% [markdown]
# **10. Variable 'aggregate_rating'**

# %%
print(df['aggregate_rating'].value_counts().head(10))  # Check the top 10 aggregate_rating in the data
# Out:
# aggregate_rating
# 0.000000    10067
# 3.900000     3600
# 3.800000     3471
# 4.000000     3392
# 3.700000     3362
# 3.600000     3029
# 3.200000     2921
# 4.100000     2850
# 3.400000     2800
# 3.300000     2792
# Name: count, dtype: int64

# %% [markdown]
# **11. Variable 'rating_text'**

# %%
print(df['rating_text'].value_counts().head(10))  # Check the top 10 rating_text in the data
# Out:
# rating_text
# Average        16338
# Good           16113
# Very Good      11154
# Not rated      10067
# Excellent       1742
# Poor             576
# Çok iyi           55
# Sangat Baik       44
# Muito Bom         43
# Excelente         34
# Name: count, dtype: int64

# %% [markdown]
# **12. Variable 'votes'**

# %%
print(df['votes'].value_counts().head(10))  # Check the top 10 votes in the data
# Out:
# votes
# 0    4616
# 1    2593
# 2    1910
# 3    1644
# 4    1607
# 6    1202
# 5    1182
# 7    1017
# 8     884
# 9     796
# Name: count, dtype: int64

# %% [markdown]
# **13. Variable 'photo_count'**

# %%
print(df['photo_count'].value_counts().head(10))  # Check the top 10 photo_count in the data
# Out:
# photo_count
# 0    10535
# 1     4215
# 2     2962
# 3     2290
# 4     1833
# 5     1536
# 6     1274
# 7     1127
# 8     1022
# 9      878
# Name: count, dtype: int64

# %% [markdown]
# **14. Variable 'delivery'**

# %%
print(df['delivery'].value_counts().head(10))  # Check the top 10 delivery in the data
# Out:
# delivery
# True     56177
# False      344
# Name: count, dtype: int64

# %% [markdown]
# <a id ='missing'></a>
# ## 6. Check for missing values

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# res_id                     0
# name                       0
# establishment           1842
# city                       0
# city_id                    0
# locality                   0
# country_id                 0
# cuisines                 470
# timings                 1008
# average_cost_for_two       0
# price_range                0
# currency                   0
# highlights               716
# aggregate_rating           0
# rating_text                0
# votes                      0
# photo_count                0
# delivery                   0
# takeaway                   0
# dtype: int64

# %%
# Fill missing values in 'establishment' column with mode values
df['establishment'] = df['establishment'].fillna(df['establishment'].mode()[0])

# Fill missing values in 'cuisines' column with mode value
df['cuisines'] = df['cuisines'].fillna(df['cuisines'].mode()[0])

# Fill missing values in 'highlights' column with mode value
df['highlights'] = df['highlights'].fillna(df['highlights'].mode()[0])

# Impute missing values in 'aggregate_rating' with median
df['aggregate_rating'] = df['aggregate_rating'].fillna(df['aggregate_rating'].median())

# Fill missing values in 'timings' column with mode value
most_frequent_timing = df['timings'].mode()[0]
df['timings'] = df['timings'].fillna(most_frequent_timing)

# Check if missing values are filled
print(df.isnull().sum())
# Out:
# res_id                  0
# name                    0
# establishment           0
# city                    0
# city_id                 0
# locality                0
# country_id              0
# cuisines                0
# timings                 0
# average_cost_for_two    0
# price_range             0
# currency                0
# highlights              0
# aggregate_rating        0
# rating_text             0
# votes                   0
# photo_count             0
# delivery                0
# takeaway                0
# dtype: int64

# %% [markdown]
# **6. Study summary statistics**

# %%
# Summary statistics
df.describe()
# Out:
#                res_id      city_id   country_id  average_cost_for_two  \
# count    56521.000000 56521.000000 56521.000000          56521.000000
# mean  13123954.260629  3383.732577     1.000000            537.235081
# std    8113345.056643  5163.777090     0.000000            602.986146
# min         50.000000     1.000000     1.000000              0.000000
# 25%    3001157.000000     8.000000     1.000000            200.000000
# 50%   18692099.000000    26.000000     1.000000            350.000000
# 75%   18869116.000000 11294.000000     1.000000            600.000000
# max   19159790.000000 11354.000000     1.000000          30000.000000
#
#        price_range  aggregate_rating        votes  photo_count
# count 56521.000000      56521.000000 56521.000000 56521.000000
# mean      1.727889          2.978435   241.591179   181.036376
# std       0.885950          1.461953   668.225580   674.606380
# min       1.000000          0.000000     0.000000     0.000000
# ...

# %% [markdown]
# <a id = 'correlation'> </a>
# ## 7. Study correlation

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=np.number)

# Correlation heatmap
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# <a id='outliers'> </a>
# ## 8. Detect outliers

# %% [markdown]
# **1. Plot the boxplot for numeric data**

# %%
# Select numeric columns
numeric_cols = df.select_dtypes(include=np.number).columns

# Determine the number of rows and columns for the subplots
num_cols = 4  # Number of columns in the subplot grid
num_rows = (len(numeric_cols) + num_cols - 1) // num_cols  # Calculate the number of rows needed

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, num_rows * 5))

# Flatten the axes array for easy iteration
axes = axes.flatten()

# Plot each numeric column in a subplot
for i, col in enumerate(numeric_cols):
    sns.boxplot(df[col], ax=axes[i])
    axes[i].set_title(f"Boxplot of {col}")

# Remove any empty subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# **2. Note the variables for which outliers are present**

# %%
# Function to identify outliers using IQR
def identify_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return outliers

# List to store columns with outliers
columns_with_outliers = []

# Check each numeric column for outliers
for col in numeric_cols:
    outliers = identify_outliers(df, col)
    if not outliers.empty:
        columns_with_outliers.append(col)

print("Columns with outliers:", columns_with_outliers)
# Out:
# Columns with outliers: ['average_cost_for_two', 'price_range', 'aggregate_rating', 'votes', 'photo_count']

# %% [markdown]
# **3. Plot the boxplot to recheck for outliers**

# %%
# Function to apply log transformation
def log_transform(column):
    return np.log1p(column)

# Function to apply square root transformation
def sqrt_transform(column):
    return np.sqrt(column)

# Apply transformations to handle outliers
df['average_cost_for_two_log'] = log_transform(df['average_cost_for_two'])
df['votes_log'] = log_transform(df['votes'])
df['photo_count_log'] = log_transform(df['photo_count'])
df['price_range'] = log_transform(df['price_range'])
df['aggregate_rating'] = log_transform(df['aggregate_rating'])

# Plot the boxplot for transformed numeric data
transformed_columns = ['average_cost_for_two_log','price_range', 'aggregate_rating','votes_log', 'photo_count_log']
plt.figure(figsize=(12, 8))
df[transformed_columns].boxplot()
plt.xticks(rotation=45)
plt.title('Boxplot for Transformed Numeric Data')
plt.show()

# %%
# Function to remove outliers using IQR
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)  # First quartile (25th percentile)
    Q3 = df[column].quantile(0.75)  # Third quartile (75th percentile)
    IQR = Q3 - Q1  # Interquartile range
    lower_bound = Q1 - 1.5 * IQR  # Lower bound
    upper_bound = Q3 + 1.5 * IQR  # Upper bound
    
    # Filter rows where the column value is within the IQR bounds
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# List of columns to check for outliers
columns_with_outliers = ['average_cost_for_two', 'price_range', 'aggregate_rating', 'votes', 'photo_count']

# Remove outliers for each column
for col in columns_with_outliers:
    if col in df.columns:  # Ensure the column exists in the dataframe
        df = remove_outliers(df, col)

# Display the dataframe shape after removing outliers
print("Dataframe shape after removing outliers:", df.shape)
# Out:
# Dataframe shape after removing outliers: (31944, 22)

# %%
# checking for outliers that are still present in the data
plt.figure(figsize=(12, 8))
df[transformed_columns].boxplot()
plt.xticks(rotation=45)
plt.title('Boxplot for Transformed Numeric Data')
plt.show()

# %% [markdown]
# <a id='region'> </a>
# ## 9. Create a new variable 'region'

# %%
# Define a mapping of cities to regions
region_map = {
    'Agra': 'North',
    'Ahmedabad': 'West',
    'Vizag': 'South',
    'Vadodara': 'West',
    # Add other mappings here
}

# Create a new column 'region' by mapping the 'city' column
df['region'] = df['city'].map(region_map)

# Display the head of the dataframe to check the new column
df.head()
# Out:
#      res_id                              name  establishment  city  city_id  \
# 8   3401284                        Cake House         Bakery  Agra       34
# 13  3400457                Yadav Dhaba Purana          Dhaba  Agra       34
# 14  3400282                             Aahar  Casual Dining  Agra       34
# 18  3400010  GMB - Gopika Sweets & Restaurant  Casual Dining  Agra       34
# 20  3400297                     Bhagat Halwai    Quick Bites  Agra       34
#
#        locality  country_id  \
# 8   Civil Lines           1
# 13  Civil Lines           1
# 14  Civil Lines           1
# 18      Tajganj           1
# 20   Dayal Bagh           1
#
#                                              cuisines  \
# 8                                   Bakery, Fast Food
# 13                                       North Indian
# 14  North Indian, South Indian, Chinese, Bakery, C...
# 18  Desserts, North Indian, South Indian, Chinese,...
# 20  Mithai, Chinese, Fast Food, Street Food, South...
#
# ...

# %% [markdown]
# <a id='more'> </a>
# ## 10. Bivariate and Multi Variate Analysis

# %%
# Bivariate Analysis: Scatter plot between 'average_cost_for_two' and 'aggregate_rating'
plt.figure(figsize=(10, 6))
sns.scatterplot(x='average_cost_for_two', y='aggregate_rating', data=df)
plt.title('Scatter plot between Average Cost for Two and Aggregate Rating')
plt.xlabel('Average Cost for Two')
plt.ylabel('Aggregate Rating')
plt.show()

# Bivariate Analysis: Box plot of 'aggregate_rating' by 'price_range'
plt.figure(figsize=(10, 6))
sns.boxplot(x='price_range', y='aggregate_rating', data=df)
plt.title('Box plot of Aggregate Rating by Price Range')
plt.xlabel('Price Range')
plt.ylabel('Aggregate Rating')
plt.show()

# Multivariate Analysis: Pair plot of selected numeric variables
selected_columns = ['average_cost_for_two', 'aggregate_rating', 'votes', 'photo_count']
sns.pairplot(df[selected_columns])
plt.show()

# Multivariate Analysis: Heatmap of correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(df[selected_columns].corr(), annot=True, cmap='coolwarm')
plt.title('Heatmap of Correlation Matrix')
plt.show()
